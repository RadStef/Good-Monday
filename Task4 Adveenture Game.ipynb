# %%
###Nora's Task4 Code

# Define the game world
rooms = {
    "Entrance": {
        "description": "You are standing at the entrance. Where would you like to go next? You can go north and east.",
        "north": "Dining Room",
        "east": "Storage Room",
    },
    "Dining Room": {
        "description": "You are in the dining room. Where would you like to go next? You can go south and east.",
        "south": "Entrance",
        "east": "Kitchen",
    },
    "Storage Room": {
        "description": "You are in a small storage room. Where would you like to go next? You can go west.",
        "west": "Entrance",
    },
    "Kitchen": {
        "description": "You are in the kitchen. Where would you like to go next? You can go west.",
        "west": "Hallway",
    },
}
# Define where the player starts
current_room = "Entrance"
def display_room(room):
    # Print the description of the current room
    room_description = rooms[room]["description"]
    print("\n" + room_description)
    # Show the player can move in different directions
    print("You can move:")
    # Print the possible directions explicitly
    if "north" in rooms[room]:
        print("  North")
    if "south" in rooms[room]:
        print("  South")
    if "east" in rooms[room]:
        print("  East")
    if "west" in rooms[room]:
        print("  West")
# Organise the game loop
while True:
    # Display the current room's details
    display_room(current_room)
    # Ask the player for input
    move = input("\nType 'move' if you would like to go to a different room or type 'quit' to stop playing: ").lower()
    # If the player wants to stop playing
    if move == "quit":
        print("Thanks for playing! Goodbye.")
        break
    elif move == "move":
        #Ask the player which direction he wants to move in?
        move = input("\nWhich direction would you like to move in?")
    # Check if the move is valid
    if move in rooms[current_room]:
        # Move the player
        current_room = rooms[current_room][move]
    else:
        # Tell the player the move is not valid
        print("\nYou can't move further in that direction. Please choose a different direction.")
# Out:
# You are standing at the entrance. Where would you like to go next? You can go north and east.
# You can move:
#   North
#   East
#
# You are in a small storage room. Where would you like to go next? You can go west.
# You can move:
#   West
#
# You are standing at the entrance. Where would you like to go next? You can go north and east.
# You can move:
#   North
#   East
#
# You can't move further in that direction. Please choose a different direction.
#
# You are standing at the entrance. Where would you like to go next? You can go north and east.
# You can move:
#   North
#   East
#
# You can't move further in that direction. Please choose a different direction.
#
# You are standing at the entrance. Where would you like to go next? You can go north and east.
# You can move:
#   North
#   East
# Thanks for playing! Goodbye.

# %%
# Game Description:
# This is a simple text-based adventure game where the player moves through rooms arranged on two floors.
# Ground floor: Room 1 (left), Room 2 (center), Room 3 (right).
# Top floor: Room 4 (above Room 1), Room 5 (above Room 2), Room 6 (above Room 3).
# Directions: "up", "down", "left", "right".

# Define the map of the game world
rooms = {
    "Room 1": {"description": "You are in Room 1 on the ground floor. There is a staircase up to Room 4 and a door to the right leading to Room 2.", "up": "Room 4", "right": "Room 2"},
    "Room 2": {"description": "You are in Room 2 on the ground floor. There are doors to the left (Room 1), right (Room 3), and stairs up to Room 5.", "left": "Room 1", "right": "Room 3", "up": "Room 5"},
    "Room 3": {"description": "You are in Room 3 on the ground floor. There is a staircase up to Room 6 and a door to the left leading to Room 2.", "up": "Room 6", "left": "Room 2"},
    "Room 4": {"description": "You are in Room 4 on the top floor. There is a staircase down to Room 1 and a door to the right leading to Room 5.", "down": "Room 1", "right": "Room 5"},
    "Room 5": {"description": "You are in Room 5 on the top floor. There are doors to the left (Room 4), right (Room 6), and stairs down to Room 2.", "left": "Room 4", "right": "Room 6", "down": "Room 2"},
    "Room 6": {"description": "You are in Room 6 on the top floor. There is a staircase down to Room 3 and a door to the left leading to Room 5.", "down": "Room 3", "left": "Room 5"},
}

# Define the player's starting position

current_room = "Room 1"

# Game instructions
print("Welcome to the our extraordinary basic Adventure - game!")
print("Here our our very basic instructions")
print("Move around using 'up', 'down', 'left', or 'right'.")
print("Type 'quit' to exit the game.\n")

# Main game loop
while True:
    # Get the description of the current room
    print(rooms[current_room]["description"])
    
    # Ask the player for their next move
    move = input("What do you want to do? ").lower()
    
    if move == "quit":
        print("Thanks for playing! Goodbye!")
        break  # Exit the game loop
    
    # Check if the move is valid
    if move in rooms[current_room]:  # Check if the move direction exists in the current room
        current_room = rooms[current_room][move]  # Update the current room
    else:
        print("You can't go that way!")  # Invalid move
# Out:
# Welcome to the our extraordinary basic Adventure - game!
# Here our our very basic instructions
# Move around using 'up', 'down', 'left', or 'right'.
# Type 'quit' to exit the game.
#
# You are in Room 1 on the ground floor. There is a staircase up to Room 4 and a door to the right leading to Room 2.
# You can't go that way!
# You are in Room 1 on the ground floor. There is a staircase up to Room 4 and a door to the right leading to Room 2.
# You are in Room 4 on the top floor. There is a staircase down to Room 1 and a door to the right leading to Room 5.
# You are in Room 5 on the top floor. There are doors to the left (Room 4), right (Room 6), and stairs down to Room 2.
# You are in Room 6 on the top floor. There is a staircase down to Room 3 and a door to the left leading to Room 5.
# You can't go that way!
# You are in Room 6 on the top floor. There is a staircase down to Room 3 and a door to the left leading to Room 5.
# You can't go that way!
# ...
